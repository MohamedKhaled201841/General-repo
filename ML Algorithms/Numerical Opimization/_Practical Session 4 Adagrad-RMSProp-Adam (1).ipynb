# %% [markdown]
# ## Name:Mohamed Khaled Ahmed Atyaa
# ## Group:3 Alex

# %% [markdown]
# ## Adagrad first trial

# %%
from sklearn.metrics import r2_score
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(0,20)
y=-1*x+2
theta_0=0
theta_1=0
v_theta_0=0
v_theta_1=0
alpha=0.1
epsilon=10**-9
max_iter=10000
h_x_list=[]
cost_fn_list=[]
theta_0_list=[]
theta_1_list=[]
m=len(x)
for i in range(max_iter):
        h_x = theta_0 + theta_1 * x
        h_x_list.append(h_x)
        cost_fn = (1 / (2 * m)) * sum(h_x - y) ** 2
        cost_fn_list.append(cost_fn)
        grad_theta0 = (1 / m) * (sum(h_x - y))
        grad_theta1 = (1 / m) * (sum((h_x - y) * x))
        v_theta_0=v_theta_0+grad_theta0**2
        v_theta_1 = v_theta_1 +grad_theta1**2
        theta_0 = theta_0 - (alpha/v_theta_0**0.5+epsilon)*grad_theta0
        theta_0_list.append(theta_0)
        theta_1 = theta_1 - (alpha/v_theta_1**0.5+epsilon)*grad_theta1
        theta_1_list.append(theta_1)
        if ((grad_theta0) ** 2 + (grad_theta1) ** 2) ** 0.5 < 0.001:
#         if i>1 and (cost_fn_list[i-1]-cost_fn_list[i] < 0.001): ##another stopping condition
         print("the # of iteration =",i)
         break

plt.figure(figsize=(16, 10), dpi=80) 
h_x=theta_0+theta_1*x
plt.subplot(2, 3, 1)
plt.scatter(x,y)
plt.plot(x,h_x,"r")
plt.xlabel("x")
plt.ylabel("y")

plt.subplot(2, 3, 2)
plt.plot(cost_fn_list)
plt.xlabel("iteration")
plt.ylabel("cost function")
plt.subplot(2, 3, 3)
plt.plot(theta_0_list,cost_fn_list)
plt.xlabel("theta_0")
plt.ylabel("cost function")
plt.subplot(2, 3, 4)
plt.plot(theta_1_list,cost_fn_list)
plt.xlabel("theta_1")
plt.ylabel("cost function")
plt.subplot(2, 3, 5)
for i in range(len(h_x_list)):
    line=h_x_list[i]
    plt.plot(x,line)
    plt.xlabel("x")
    plt.ylabel("h(x)")
    
plt.legend(["alpha=0.1", "epislon=1e-9", "max # of iters=10000","The R2 score of Adagrad = 0.9999999349961797","the # of iteration = 6599"], title='first trail of Adagrad', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()
print("The R2 score of Adagrad = ",r2_score(y,h_x))
# Out:
# the # of iteration = 6599
# The R2 score of Adagrad =  0.9999999349961797

# %% [markdown]
# ## Adagrad second trial

# %%
from sklearn.metrics import r2_score
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 20)
y = -1 * x + 2
theta_0 = 0
theta_1 = 0
v_theta_0 = 0
v_theta_1 = 0
alpha = 0.01
epsilon = 1e-8
max_iter = 10000
h_x_list = []
cost_fn_list = []
theta_0_list = []
theta_1_list = []
m = len(x)
for i in range(max_iter):
    h_x = theta_0 + theta_1 * x
    h_x_list.append(h_x)
    cost_fn = (1 / (2 * m)) * sum(h_x - y) ** 2
    cost_fn_list.append(cost_fn)
    grad_theta0 = (1 / m) * (sum(h_x - y))
    grad_theta1 = (1 / m) * (sum((h_x - y) * x))
    v_theta_0 = v_theta_0 + grad_theta0 ** 2
    v_theta_1 = v_theta_1 + grad_theta1 ** 2
    theta_0 = theta_0 - (alpha / v_theta_0 ** 0.5 + epsilon) * grad_theta0
    theta_0_list.append(theta_0)
    theta_1 = theta_1 - (alpha / v_theta_1 ** 0.5 + epsilon) * grad_theta1
    theta_1_list.append(theta_1)
    # if ((grad_theta0) ** 2 + (grad_theta1) ** 2) ** 0.5 < 0.001:
    if i>1 and (cost_fn_list[i-1]-cost_fn_list[i] < 0.001): ##another stopping condition
        print("the # of iteration =", i)
        break

plt.figure(figsize=(16, 10), dpi=80)
h_x = theta_0 + theta_1 * x
plt.subplot(2, 3, 1)
plt.scatter(x, y)
plt.plot(x, h_x, "r")
plt.xlabel("x")
plt.ylabel("y")

plt.subplot(2, 3, 2)
plt.plot(cost_fn_list)
plt.xlabel("iteration")
plt.ylabel("cost function")
plt.subplot(2, 3, 3)
plt.plot(theta_0_list, cost_fn_list)
plt.xlabel("theta_0")
plt.ylabel("cost function")
plt.subplot(2, 3, 4)
plt.plot(theta_1_list, cost_fn_list)
plt.xlabel("theta_1")
plt.ylabel("cost function")
plt.subplot(2, 3, 5)
for i in range(len(h_x_list)):
    line = h_x_list[i]
    plt.plot(x, line)
    plt.xlabel("x")
    plt.ylabel("h(x)")

plt.legend(["alpha=0.01", "epislon=1e-8", "max # of iters=10000","The R2 score of Adagrad =0.9275864373382198","the # of iteration = 3289"], title='second trail of Adagrad',
           bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()
print("The R2 score of Adagrad = ", r2_score(y, h_x))
# Out:
# the # of iteration = 3289
# The R2 score of Adagrad =  0.9275864373382198

# %% [markdown]
# ## First trail of RMSProp

# %%
from sklearn.metrics import r2_score
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(0,20)
y=-1*x+2
theta_0=0
theta_1=0
v_theta_0=0
v_theta_1=0
alpha=0.01
epsilon=1e-8
beta=0.9
max_iter=1000
h_x_list=[]
cost_fn_list=[]
theta_0_list=[]
theta_1_list=[]
m=len(x)
for i in range(max_iter):
        h_x = theta_0 + theta_1 * x
        h_x_list.append(h_x)
        cost_fn = (1 / (2 * m)) * sum(h_x - y) ** 2
        cost_fn_list.append(cost_fn)
        grad_theta0 = (1 / m) * (sum(h_x - y))
        grad_theta1 = (1 / m) * (sum((h_x - y) * x))
        v_theta_0=beta*v_theta_0+(1-beta)*grad_theta0**2
        v_theta_1 = beta*v_theta_1 +(1-beta)*grad_theta1**2
        theta_0 = theta_0 - (alpha/(v_theta_0**0.5+epsilon))*grad_theta0
        theta_0_list.append(theta_0)
        theta_1 = theta_1 - (alpha/(v_theta_1**0.5+epsilon))*grad_theta1
        theta_1_list.append(theta_1)
        # if ((grad_theta0) ** 2 + (grad_theta1) ** 2) ** 0.5 < 0.001:
        if i > 1 and (cost_fn_list[i - 1] - cost_fn_list[i] < 0.001):
            print("the # of iteration =",i)
            break
plt.figure(figsize=(16, 10), dpi=80)
h_x=theta_0+theta_1*x
plt.subplot(2, 3, 1)
plt.scatter(x,y)
plt.plot(x,h_x,"r")
plt.xlabel("x")
plt.ylabel("y")

plt.subplot(2, 3, 2)
plt.plot(cost_fn_list)
plt.xlabel("iteration")
plt.ylabel("cost function")
plt.subplot(2, 3, 3)
plt.plot(theta_0_list,cost_fn_list)
plt.xlabel("theta_0")
plt.ylabel("cost function")
plt.subplot(2, 3, 4)
plt.plot(theta_1_list,cost_fn_list)
plt.xlabel("theta_1")
plt.ylabel("cost function")
plt.subplot(2, 3, 5)
for i in range(len(h_x_list)):
    line = h_x_list[i]
    plt.plot(x, line)
    plt.xlabel("x")
    plt.ylabel("h(x)")
plt.legend(["alpha=0.01", "epislon=1e-8","beta=0.9", "max # of iters=10000","The R2 score of Adagrad =0.9337029006891749","the # of iteration = 83"], title='First trail of RMSProp',
           bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
print("The R2 score of RMSProp = ", r2_score(y, h_x))
# Out:
# the # of iteration = 83
# The R2 score of RMSProp =  0.9337029006891749

# %% [markdown]
# ## Second trail of RMSProp

# %%
from sklearn.metrics import r2_score
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(0,20)
y=-1*x+2
theta_0=0
theta_1=0
v_theta_0=0
v_theta_1=0
alpha=0.001
epsilon=1e-8
beta=0.95
max_iter=1000
h_x_list=[]
cost_fn_list=[]
theta_0_list=[]
theta_1_list=[]
m=len(x)
for i in range(max_iter):
        h_x = theta_0 + theta_1 * x
        h_x_list.append(h_x)
        cost_fn = (1 / (2 * m)) * sum(h_x - y) ** 2
        cost_fn_list.append(cost_fn)
        grad_theta0 = (1 / m) * (sum(h_x - y))
        grad_theta1 = (1 / m) * (sum((h_x - y) * x))
        v_theta_0=beta*v_theta_0+(1-beta)*grad_theta0**2
        v_theta_1 = beta*v_theta_1 +(1-beta)*grad_theta1**2
        theta_0 = theta_0 - (alpha/(v_theta_0**0.5+epsilon))*grad_theta0
        theta_0_list.append(theta_0)
        theta_1 = theta_1 - (alpha/(v_theta_1**0.5+epsilon))*grad_theta1
        theta_1_list.append(theta_1)
        # if ((grad_theta0) ** 2 + (grad_theta1) ** 2) ** 0.5 < 0.001:
        if i > 1 and (cost_fn_list[i - 1] - cost_fn_list[i] < 0.001):
            print("the # of iteration =",i)
            break
plt.figure(figsize=(16, 10), dpi=80)
h_x=theta_0+theta_1*x
plt.subplot(2, 3, 1)
plt.scatter(x,y)
plt.plot(x,h_x,"r")
plt.xlabel("x")
plt.ylabel("y")

plt.subplot(2, 3, 2)
plt.plot(cost_fn_list)
plt.xlabel("iteration")
plt.ylabel("cost function")
plt.subplot(2, 3, 3)
plt.plot(theta_0_list,cost_fn_list)
plt.xlabel("theta_0")
plt.ylabel("cost function")
plt.subplot(2, 3, 4)
plt.plot(theta_1_list,cost_fn_list)
plt.xlabel("theta_1")
plt.ylabel("cost function")
plt.subplot(2, 3, 5)
for i in range(len(h_x_list)):
    line = h_x_list[i]
    plt.plot(x, line)
    plt.xlabel("x")
    plt.ylabel("h(x)")
plt.legend(["alpha=0.001", "epislon=1e-8","beta=0.95", "max # of iters=10000","The R2 score of Adagrad =0.9280605086438082","the # of iteration = 755"], title='Second trail of RMSProp',
           bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
print("The R2 score of RMSProp = ", r2_score(y, h_x))
# Out:
# the # of iteration = 755
# The R2 score of RMSProp =  0.9280605086438082

# %% [markdown]
# ## First trail of  Adam with correction bias

# %%
from sklearn.metrics import r2_score
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(0,20)
y=-1*x+2
theta_0=0
theta_1=0
m_theta_0=0
m_theta_1=0
v_theta_0=0
v_theta_1=0
alpha=0.01
epsilon=1e-8
beta_1=0.9
beta_2=0.999
max_iter=10000
h_x_list=[]
cost_fn_list=[]
theta_0_list=[]
theta_1_list=[]
m=len(x)
for i in range(max_iter):
        h_x = theta_0 + theta_1 * x
        h_x_list.append(h_x)
        cost_fn = (1 / (2 * m)) * sum(h_x - y) ** 2
        cost_fn_list.append(cost_fn)
        grad_theta0 = (1 / m) * (sum(h_x - y))
        grad_theta1 = (1 / m) * (sum((h_x - y) * x))
        m_theta_0 = beta_1 * m_theta_0 + (1 - beta_1) * grad_theta0
        m_theta_1 = beta_1 * m_theta_1 + (1 - beta_1) * grad_theta1
        m_theta_0_correction = m_theta_0/(1-beta_1**i+1)
        m_theta_1_correction = m_theta_1/(1-beta_1**i+1)
        v_theta_0=beta_2*v_theta_0+(1-beta_2)*grad_theta0**2
        v_theta_1 = beta_2*v_theta_1 +(1-beta_2)*grad_theta1**2
        v_theta_0_correction = v_theta_0 / (1 - beta_2 ** i+1)
        v_theta_1_correction = v_theta_1 / (1 - beta_2 ** i+1)
        theta_0 = theta_0 - (alpha/(v_theta_0_correction**0.5+epsilon))* m_theta_0_correction
        theta_0_list.append(theta_0)
        theta_1 = theta_1 - (alpha/(v_theta_1_correction**0.5+epsilon))* m_theta_1_correction
        theta_1_list.append(theta_1)
        if ((grad_theta0) ** 2 + (grad_theta1) ** 2) ** 0.5 < 0.001:
        # if i > 1 and (cost_fn_list[i - 1] - cost_fn_list[i] < 0.001):
            print("the # of iteration =",i)
            break
plt.figure(figsize=(16, 9), dpi=80)
h_x=theta_0+theta_1*x
plt.subplot(2, 3, 1)
plt.scatter(x,y)
plt.plot(x,h_x,"r")
plt.xlabel("x")
plt.ylabel("y")

plt.subplot(2, 3, 2)
plt.plot(cost_fn_list)
plt.xlabel("iteration")
plt.ylabel("cost function")
plt.subplot(2, 3, 3)
plt.plot(theta_0_list,cost_fn_list)
plt.xlabel("theta_0")
plt.ylabel("cost function")
plt.subplot(2, 3, 4)
plt.plot(theta_1_list,cost_fn_list)
plt.xlabel("theta_1")
plt.ylabel("cost function")
plt.subplot(2, 3, 5)
for i in range(len(h_x_list)):
    line = h_x_list[i]
    plt.plot(x, line)
    plt.xlabel("x")
    plt.ylabel("h(x)")
plt.legend(["alpha=0.01", "epislon=1e-8","beta1=0.9","beta2=0.999", "max # of iters=10000","The R2 score of Adagrad =0.9999999350418448","the # of iteration = 1968"], title='First trail of  Adam with correction bias',
           bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
print("The R2 score of Adam with correction bias = ", r2_score(y, h_x))
# Out:
# the # of iteration = 1968
# The R2 score of Adam with correction bias =  0.9999999350418448

# %% [markdown]
# ## Second trail of  Adam with correction bias

# %%
from sklearn.metrics import r2_score
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(0,20)
y=-1*x+2
theta_0=0
theta_1=0
m_theta_0=0
m_theta_1=0
v_theta_0=0
v_theta_1=0
alpha=0.05
epsilon=1e-8
beta_1=0.7
beta_2=0.9
max_iter=10000
h_x_list=[]
cost_fn_list=[]
theta_0_list=[]
theta_1_list=[]
m=len(x)
for i in range(max_iter):
        h_x = theta_0 + theta_1 * x
        h_x_list.append(h_x)
        cost_fn = (1 / (2 * m)) * sum(h_x - y) ** 2
        cost_fn_list.append(cost_fn)
        grad_theta0 = (1 / m) * (sum(h_x - y))
        grad_theta1 = (1 / m) * (sum((h_x - y) * x))
        m_theta_0 = beta_1 * m_theta_0 + (1 - beta_1) * grad_theta0
        m_theta_1 = beta_1 * m_theta_1 + (1 - beta_1) * grad_theta1
        m_theta_0_correction = m_theta_0/(1-beta_1**i+1)
        m_theta_1_correction = m_theta_1/(1-beta_1**i+1)
        v_theta_0=beta_2*v_theta_0+(1-beta_2)*grad_theta0**2
        v_theta_1 = beta_2*v_theta_1 +(1-beta_2)*grad_theta1**2
        v_theta_0_correction = v_theta_0 / (1 - beta_2 ** i+1)
        v_theta_1_correction = v_theta_1 / (1 - beta_2 ** i+1)
        theta_0 = theta_0 - (alpha/(v_theta_0_correction**0.5+epsilon))* m_theta_0_correction
        theta_0_list.append(theta_0)
        theta_1 = theta_1 - (alpha/(v_theta_1_correction**0.5+epsilon))* m_theta_1_correction
        theta_1_list.append(theta_1)
        if ((grad_theta0) ** 2 + (grad_theta1) ** 2) ** 0.5 < 0.001:
        # if i > 1 and (cost_fn_list[i - 1] - cost_fn_list[i] < 0.001):
            print("the # of iteration =",i)
            break
plt.figure(figsize=(16, 9), dpi=80)
h_x=theta_0+theta_1*x
plt.subplot(2, 3, 1)
plt.scatter(x,y)
plt.plot(x,h_x,"r")
plt.xlabel("x")
plt.ylabel("y")

plt.subplot(2, 3, 2)
plt.plot(cost_fn_list)
plt.xlabel("iteration")
plt.ylabel("cost function")
plt.subplot(2, 3, 3)
plt.plot(theta_0_list,cost_fn_list)
plt.xlabel("theta_0")
plt.ylabel("cost function")
plt.subplot(2, 3, 4)
plt.plot(theta_1_list,cost_fn_list)
plt.xlabel("theta_1")
plt.ylabel("cost function")
plt.subplot(2, 3, 5)
for i in range(len(h_x_list)):
    line = h_x_list[i]
    plt.plot(x, line)
    plt.xlabel("x")
    plt.ylabel("h(x)")
plt.legend(["alpha=0.05", "epislon=1e-8","beta1=0.7","beta2=0.9", "max # of iters=10000","The R2 score of Adagrad =0.9999863491932517","the # of iteration = 946"], title='Second trail of  Adam with correction bias',
           bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
print("The R2 score of Adam with correction bias = ", r2_score(y, h_x))
# Out:
# the # of iteration = 946
# The R2 score of Adam with correction bias =  0.9999863491932517

# %% [markdown]
# ## Comparison between the three algorithms

# %% [markdown]
# ## Adagrad

# %%
from sklearn.metrics import r2_score
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 20)
y = -1 * x + 2
theta_0 = 0
theta_1 = 0
v_theta_0 = 0
v_theta_1 = 0
alpha = 0.01
epsilon = 1e-8
max_iter = 10000
h_x_list = []
cost_fn_list = []
theta_0_list = []
theta_1_list = []
m = len(x)
for i in range(max_iter):
    h_x = theta_0 + theta_1 * x
    h_x_list.append(h_x)
    cost_fn = (1 / (2 * m)) * sum(h_x - y) ** 2
    cost_fn_list.append(cost_fn)
    grad_theta0 = (1 / m) * (sum(h_x - y))
    grad_theta1 = (1 / m) * (sum((h_x - y) * x))
    v_theta_0 = v_theta_0 + grad_theta0 ** 2
    v_theta_1 = v_theta_1 + grad_theta1 ** 2
    theta_0 = theta_0 - (alpha / v_theta_0 ** 0.5 + epsilon) * grad_theta0
    theta_0_list.append(theta_0)
    theta_1 = theta_1 - (alpha / v_theta_1 ** 0.5 + epsilon) * grad_theta1
    theta_1_list.append(theta_1)
    # if ((grad_theta0) ** 2 + (grad_theta1) ** 2) ** 0.5 < 0.001:
    if i>1 and (cost_fn_list[i-1]-cost_fn_list[i] < 0.001): ##another stopping condition
        print("the # of iteration =", i)
        break

plt.figure(figsize=(16, 10), dpi=80)
h_x = theta_0 + theta_1 * x
plt.subplot(2, 3, 1)
plt.scatter(x, y)
plt.plot(x, h_x, "r")
plt.xlabel("x")
plt.ylabel("y")

plt.subplot(2, 3, 2)
plt.plot(cost_fn_list)
plt.xlabel("iteration")
plt.ylabel("cost function")
plt.subplot(2, 3, 3)
plt.plot(theta_0_list, cost_fn_list)
plt.xlabel("theta_0")
plt.ylabel("cost function")
plt.subplot(2, 3, 4)
plt.plot(theta_1_list, cost_fn_list)
plt.xlabel("theta_1")
plt.ylabel("cost function")
plt.subplot(2, 3, 5)
for i in range(len(h_x_list)):
    line = h_x_list[i]
    plt.plot(x, line)
    plt.xlabel("x")
    plt.ylabel("h(x)")

plt.legend(["alpha=0.01", "epislon=1e-8", "max # of iters=10000","The R2 score of Adagrad =0.9275864373382198","the # of iteration = 3289"], title=' Adagrad',
           bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()
print("The R2 score of Adagrad = ", r2_score(y, h_x))
# Out:
# the # of iteration = 3289
# The R2 score of Adagrad =  0.9275864373382198

# %% [markdown]
# ## RMSProp

# %%
from sklearn.metrics import r2_score
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(0,20)
y=-1*x+2
theta_0=0
theta_1=0
v_theta_0=0
v_theta_1=0
alpha=0.01
epsilon=1e-8
beta=0.9
max_iter=1000
h_x_list=[]
cost_fn_list=[]
theta_0_list=[]
theta_1_list=[]
m=len(x)
for i in range(max_iter):
        h_x = theta_0 + theta_1 * x
        h_x_list.append(h_x)
        cost_fn = (1 / (2 * m)) * sum(h_x - y) ** 2
        cost_fn_list.append(cost_fn)
        grad_theta0 = (1 / m) * (sum(h_x - y))
        grad_theta1 = (1 / m) * (sum((h_x - y) * x))
        v_theta_0=beta*v_theta_0+(1-beta)*grad_theta0**2
        v_theta_1 = beta*v_theta_1 +(1-beta)*grad_theta1**2
        theta_0 = theta_0 - (alpha/(v_theta_0**0.5+epsilon))*grad_theta0
        theta_0_list.append(theta_0)
        theta_1 = theta_1 - (alpha/(v_theta_1**0.5+epsilon))*grad_theta1
        theta_1_list.append(theta_1)
        # if ((grad_theta0) ** 2 + (grad_theta1) ** 2) ** 0.5 < 0.001:
        if i > 1 and (cost_fn_list[i - 1] - cost_fn_list[i] < 0.001):
            print("the # of iteration =",i)
            break
plt.figure(figsize=(16, 10), dpi=80)
h_x=theta_0+theta_1*x
plt.subplot(2, 3, 1)
plt.scatter(x,y)
plt.plot(x,h_x,"r")
plt.xlabel("x")
plt.ylabel("y")

plt.subplot(2, 3, 2)
plt.plot(cost_fn_list)
plt.xlabel("iteration")
plt.ylabel("cost function")
plt.subplot(2, 3, 3)
plt.plot(theta_0_list,cost_fn_list)
plt.xlabel("theta_0")
plt.ylabel("cost function")
plt.subplot(2, 3, 4)
plt.plot(theta_1_list,cost_fn_list)
plt.xlabel("theta_1")
plt.ylabel("cost function")
plt.subplot(2, 3, 5)
for i in range(len(h_x_list)):
    line = h_x_list[i]
    plt.plot(x, line)
    plt.xlabel("x")
    plt.ylabel("h(x)")
plt.legend(["alpha=0.01", "epislon=1e-8","beta=0.9", "max # of iters=10000","The R2 score of Adagrad =0.9337029006891749","the # of iteration = 83"], title=' RMSProp',
           bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
print("The R2 score of RMSProp = ", r2_score(y, h_x))
# Out:
# the # of iteration = 83
# The R2 score of RMSProp =  0.9337029006891749

# %% [markdown]
# ##  Adam with correction bias

# %%
from sklearn.metrics import r2_score
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(0,20)
y=-1*x+2
theta_0=0
theta_1=0
m_theta_0=0
m_theta_1=0
v_theta_0=0
v_theta_1=0
alpha=0.01
epsilon=1e-8
beta_1=0.9
beta_2=0.9
max_iter=10000
h_x_list=[]
cost_fn_list=[]
theta_0_list=[]
theta_1_list=[]
m=len(x)
for i in range(max_iter):
        h_x = theta_0 + theta_1 * x
        h_x_list.append(h_x)
        cost_fn = (1 / (2 * m)) * sum(h_x - y) ** 2
        cost_fn_list.append(cost_fn)
        grad_theta0 = (1 / m) * (sum(h_x - y))
        grad_theta1 = (1 / m) * (sum((h_x - y) * x))
        m_theta_0 = beta_1 * m_theta_0 + (1 - beta_1) * grad_theta0
        m_theta_1 = beta_1 * m_theta_1 + (1 - beta_1) * grad_theta1
        m_theta_0_correction = m_theta_0/(1-beta_1**i+1)
        m_theta_1_correction = m_theta_1/(1-beta_1**i+1)
        v_theta_0=beta_2*v_theta_0+(1-beta_2)*grad_theta0**2
        v_theta_1 = beta_2*v_theta_1 +(1-beta_2)*grad_theta1**2
        v_theta_0_correction = v_theta_0 / (1 - beta_2 ** i+1)
        v_theta_1_correction = v_theta_1 / (1 - beta_2 ** i+1)
        theta_0 = theta_0 - (alpha/(v_theta_0_correction**0.5+epsilon))* m_theta_0_correction
        theta_0_list.append(theta_0)
        theta_1 = theta_1 - (alpha/(v_theta_1_correction**0.5+epsilon))* m_theta_1_correction
        theta_1_list.append(theta_1)
        if ((grad_theta0) ** 2 + (grad_theta1) ** 2) ** 0.5 < 0.001:
        # if i > 1 and (cost_fn_list[i - 1] - cost_fn_list[i] < 0.001):
            print("the # of iteration =",i)
            break
plt.figure(figsize=(16, 9), dpi=80)
h_x=theta_0+theta_1*x
plt.subplot(2, 3, 1)
plt.scatter(x,y)
plt.plot(x,h_x,"r")
plt.xlabel("x")
plt.ylabel("y")

plt.subplot(2, 3, 2)
plt.plot(cost_fn_list)
plt.xlabel("iteration")
plt.ylabel("cost function")
plt.subplot(2, 3, 3)
plt.plot(theta_0_list,cost_fn_list)
plt.xlabel("theta_0")
plt.ylabel("cost function")
plt.subplot(2, 3, 4)
plt.plot(theta_1_list,cost_fn_list)
plt.xlabel("theta_1")
plt.ylabel("cost function")
plt.subplot(2, 3, 5)
for i in range(len(h_x_list)):
    line = h_x_list[i]
    plt.plot(x, line)
    plt.xlabel("x")
    plt.ylabel("h(x)")
plt.legend(["alpha=0.05", "epislon=1e-8","beta1=0.7","beta2=0.9", "max # of iters=10000","The R2 score of Adagrad = 0.9999998244082575","the # of iteration = 664"], title='  Adam with correction bias',
           bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
print("The R2 score of Adam with correction bias = ", r2_score(y, h_x))
# Out:
# the # of iteration = 664
# The R2 score of Adam with correction bias =  0.9999998244082575

# %% [markdown]
# ## we see from the iteration point of view RMSprop is the best the adam then Adagrad
# ## from the r2 score point of view adam is the ultimate best
